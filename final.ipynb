# %%
# clone YOLOv5 repository
# !git clone https://github.com/ultralytics/yolov5  # clone repo
# %cd yolov5
#!git reset --hard 886f1c03d839575afecb059accf74296fad395b6
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 13286, done.
# remote: Total 13286 (delta 0), reused 0 (delta 0), pack-reused 13286
# Receiving objects: 100% (13286/13286), 12.03 MiB | 7.15 MiB/s, done.
# Resolving deltas: 100% (9253/9253), done.
# /content/yolov5

# %%
# Weights & Biases  (optional)
# %pip install -q wandb
import wandb
wandb.login()
# Out:
#      |████████████████████████████████| 1.8 MB 15.5 MB/s
#      |████████████████████████████████| 144 kB 64.5 MB/s
#      |████████████████████████████████| 181 kB 56.4 MB/s
#      |████████████████████████████████| 63 kB 2.1 MB/s
#   Building wheel for pathtools (setup.py) ... done
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit: ··········
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# True

# %%
# install dependencies as necessary
# !pip install -qr requirements.txt  # install dependencies (ignore errors)
import torch

from IPython.display import Image, clear_output  # to display images
#from utils.google_utils import gdrive_download  # to download models/datasets

# clear_output()
print('Setup complete. Using torch %s %s' % (torch.__version__, torch.cuda.get_device_properties(0) if torch.cuda.is_available() else 'CPU'))
# Out:
#      |████████████████████████████████| 596 kB 14.1 MB/s
# Setup complete. Using torch 1.11.0+cu113 _CudaDeviceProperties(name='Tesla T4', major=7, minor=5, total_memory=15109MB, multi_processor_count=40)

# %%
#follow the link below to get your download code from from Roboflow
# !pip install -q roboflow
from roboflow import Roboflow
rf = Roboflow(model_format="yolov5", notebook="roboflow-yolov5")
# Out:
#      |████████████████████████████████| 145 kB 14.6 MB/s
#      |████████████████████████████████| 178 kB 68.0 MB/s
#      |████████████████████████████████| 1.1 MB 53.5 MB/s
#      |████████████████████████████████| 67 kB 6.8 MB/s
#      |████████████████████████████████| 54 kB 3.3 MB/s
#      |████████████████████████████████| 138 kB 69.8 MB/s
#      |████████████████████████████████| 63 kB 2.1 MB/s
#   Building wheel for roboflow (setup.py) ... done
#   Building wheel for wget (setup.py) ... done
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests~=2.23.0, but you have requests 2.27.1 which is incompatible.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# albumentations 0.1.12 requires imgaug<0.2.7,>=0.2.5, but you have imgaug 0.2.9 which is incompatible.
# upload and label your dataset, and get an API KEY here: https://app.roboflow.com/?model=yolov5&ref=roboflow-yolov5

# %%
# set up environment
import os
os.environ["DATASET_DIRECTORY"] = "/content/datasets"

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="oQNpoPBayWmcuth9rETl")
project = rf.workspace().project("dataset-4aafs")
dataset = project.version(1).download("yolov5")
# Out:
# Requirement already satisfied: roboflow in /usr/local/lib/python3.7/dist-packages (0.2.4)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from roboflow) (1.15.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.7/dist-packages (from roboflow) (3.2.2)
# Requirement already satisfied: opencv-python>=4.1.2 in /usr/local/lib/python3.7/dist-packages (from roboflow) (4.1.2.30)
# Requirement already satisfied: requests-toolbelt in /usr/local/lib/python3.7/dist-packages (from roboflow) (0.9.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from roboflow) (2.27.1)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.7/dist-packages (from roboflow) (1.21.6)
# Requirement already satisfied: chardet==4.0.0 in /usr/local/lib/python3.7/dist-packages (from roboflow) (4.0.0)
# Requirement already satisfied: certifi==2021.5.30 in /usr/local/lib/python3.7/dist-packages (from roboflow) (2021.5.30)
# Requirement already satisfied: cycler==0.10.0 in /usr/local/lib/python3.7/dist-packages (from roboflow) (0.10.0)
# Requirement already satisfied: python-dotenv in /usr/local/lib/python3.7/dist-packages (from roboflow) (0.20.0)
# Requirement already satisfied: kiwisolver==1.3.1 in /usr/local/lib/python3.7/dist-packages (from roboflow) (1.3.1)
# Requirement already satisfied: Pillow>=7.1.2 in /usr/local/lib/python3.7/dist-packages (from roboflow) (7.1.2)
# Requirement already satisfied: wget in /usr/local/lib/python3.7/dist-packages (from roboflow) (3.2)
# Requirement already satisfied: urllib3==1.26.6 in /usr/local/lib/python3.7/dist-packages (from roboflow) (1.26.6)
# Requirement already satisfied: PyYAML>=5.3.1 in /usr/local/lib/python3.7/dist-packages (from roboflow) (6.0)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.7/dist-packages (from roboflow) (2.8.2)
# Requirement already satisfied: pyparsing==2.4.7 in /usr/local/lib/python3.7/dist-packages (from roboflow) (2.4.7)
# Requirement already satisfied: idna==2.10 in /usr/local/lib/python3.7/dist-packages (from roboflow) (2.10)
# Requirement already satisfied: tqdm>=4.41.0 in /usr/local/lib/python3.7/dist-packages (from roboflow) (4.64.0)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.7/dist-packages (from requests->roboflow) (2.0.12)
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in /content/datasets/Dataset-1 to yolov5pytorch: 100% [45205762 / 45205762] bytes
# Extracting Dataset Version Zip to /content/datasets/Dataset-1 in yolov5pytorch:: 100%|██████████| 746/746 [00:00<00:00, 1101.49it/s]

# %%
# this is the YAML file Roboflow wrote for us that we're loading into this notebook with our data
print('dataset value:',dataset.location) 

# %cat {dataset.location}/data.yaml
# Out:
# dataset value: /content/datasets/Dataset-1
# names: [Broken trash can, Full trash can, Healthy trash can]
# nc: 3
# train: /content/datasets/Dataset-1/train/images
# val: /content/datasets/Dataset-1/valid/images

# %%
# define number of classes based on YAML
import yaml
with open(dataset.location + "/data.yaml", 'r') as stream:
    num_classes = str(yaml.safe_load(stream)['nc'])

# %%
# %cat /content/yolov5/models/yolov5l.yaml
# Out:
# # YOLOv5 🚀 by Ultralytics, GPL-3.0 license
#
# # Parameters
# nc: 80  # number of classes
# depth_multiple: 1.0  # model depth multiple
# width_multiple: 1.0  # layer channel multiple
# anchors:
#   - [10,13, 16,30, 33,23]  # P3/8
#   - [30,61, 62,45, 59,119]  # P4/16
#   - [116,90, 156,198, 373,326]  # P5/32
#
# # YOLOv5 v6.0 backbone
# backbone:
#   # [from, number, module, args]
#   [[-1, 1, Conv, [64, 6, 2, 2]],  # 0-P1/2
#    [-1, 1, Conv, [128, 3, 2]],  # 1-P2/4
#    [-1, 3, C3, [128]],
#    [-1, 1, Conv, [256, 3, 2]],  # 3-P3/8
#    [-1, 6, C3, [256]],
#    [-1, 1, Conv, [512, 3, 2]],  # 5-P4/16
#    [-1, 9, C3, [512]],
#    [-1, 1, Conv, [1024, 3, 2]],  # 7-P5/32
#    [-1, 3, C3, [1024]],
#    [-1, 1, SPPF, [1024, 5]],  # 9
#   ]
#
# # YOLOv5 v6.0 head
# head:
#   [[-1, 1, Conv, [512, 1, 1]],
#    [-1, 1, nn.Upsample, [None, 2, 'nearest']],
#    [[-1, 6], 1, Concat, [1]],  # cat backbone P4
#    [-1, 3, C3, [512, False]],  # 13
#
#    [-1, 1, Conv, [256, 1, 1]],
#    [-1, 1, nn.Upsample, [None, 2, 'nearest']],
#    [[-1, 4], 1, Concat, [1]],  # cat backbone P3
#    [-1, 3, C3, [256, False]],  # 17 (P3/8-small)
#
#    [-1, 1, Conv, [256, 3, 2]],
#    [[-1, 14], 1, Concat, [1]],  # cat head P4
#    [-1, 3, C3, [512, False]],  # 20 (P4/16-medium)
#
#    [-1, 1, Conv, [512, 3, 2]],
#    [[-1, 10], 1, Concat, [1]],  # cat head P5
#    [-1, 3, C3, [1024, False]],  # 23 (P5/32-large)
#
#    [[17, 20, 23], 1, Detect, [nc, anchors]],  # Detect(P3, P4, P5)
#   ]

# %%
 import torch
 torch.cuda.empty_cache()

# %%
torch.cuda.memory_summary(device=None, abbreviated=False)
# Out:
# '|===========================================================================|\n|                  PyTorch CUDA memory summary, device ID 0                 |\n|---------------------------------------------------------------------------|\n|            CUDA OOMs: 0            |        cudaMalloc retries: 0         |\n|===========================================================================|\n|        Metric         | Cur Usage  | Peak Usage | Tot Alloc  | Tot Freed  |\n|---------------------------------------------------------------------------|\n| Allocated memory      |       0 B  |       0 B  |       0 B  |       0 B  |\n|       from large pool |       0 B  |       0 B  |       0 B  |       0 B  |\n|       from small pool |       0 B  |       0 B  |       0 B  |       0 B  |\n|---------------------------------------------------------------------------|\n| Active memory         |       0 B  |       0 B  |       0 B  |       0 B  |\n|       from large pool |       0 B  |       0 B  |       0 B  |       0 B  |\n|       from small pool |       0 B  |       0 B  |       0 B  |       0 B  |\n|---------------------------------------------------------------------------|\n| GPU reserved memory   |       0 B  |       0 B  |       0 B  |       0 B  |\n|       from large pool |       0 B  |       0 B  |       0 B  |       0 B  |\n|       from small pool |       0 B  |       0 B  |       0 B  |       0 B  |\n|---------------------------------------------------------------------------|\n| Non-releasable memory |       0 B  |       0 B  |       0 B  |       0 B  |\n|       from large pool |       0 B  |       0 B  |       0 B  |       0 B  |\n|       from small pool |       0 B  |       0 B  |       0 B  |       0 B  |\n|---------------------------------------------------------------------------|\n| Allocations           |       0    |       0    |       0    |       0    |\n|       from large pool |       0    |       0    |       0    |       0    |\n|       from small pool |       0    |       0    |       0    |       0    |\n|---------------------------------------------------------------------------|\n| Active allocs         |       0    |       0    |       0    |       0    |\n|       from large pool |       0    |       0    |       0    |       0    |\n|       from small pool |       0    |       0    |       0    |       0    |\n|---------------------------------------------------------------------------|\n| GPU reserved segments |       0    |       0    |       0    |       0    |\n|       from large pool |       0    |       0    |       0    |       0    |\n|       from small pool |       0    |       0    |       0    |       0    |\n|---------------------------------------------------------------------------|\n| Non-releasable allocs |       0    |       0    |       0    |       0    |\n|       from large pool |       0    |       0    |       0    |       0    |\n|       from small pool |       0    |       0    |       0    |       0    |\n|---------------------------------------------------------------------------|\n| Oversize allocations  |       0    |       0    |       0    |       0    |\n|---------------------------------------------------------------------------|\n| Oversize GPU segments |       0    |       0    |       0    |       0    |\n|===========================================================================|\n'

# %%
# !python train.py --img 416  --batch 8 --epochs 600 --data {dataset.location}/data.yaml --weights yolov5l.pt --cache --upload_data val --save-period 1
# Out:
# wandb: Currently logged in as: amir25. Use `wandb login --relogin` to force relogin
# train: weights=yolov5l.pt, cfg=, data=/content/datasets/Dataset-1/data.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=600, batch_size=8, imgsz=416, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=1, local_rank=-1, entity=None, upload_dataset=val, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v6.1-177-gd059d1d torch 1.11.0+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# hyperparameters: lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.5, cls_pw=1.0, obj=1.0, obj_pw=1.0, iou_t=0.2, anchor_t=4.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0
# TensorBoard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# wandb: Tracking run with wandb version 0.12.16
# wandb: Run data is saved locally in /content/yolov5/wandb/run-20220509_193738-2c4ys4nv
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run peach-cloud-2
# wandb: ⭐️ View project at https://wandb.ai/amir25/YOLOv5
# wandb: 🚀 View run at https://wandb.ai/amir25/YOLOv5/runs/2c4ys4nv
# Downloading https://ultralytics.com/assets/Arial.ttf to /root/.config/Ultralytics/Arial.ttf...
# 100% 755k/755k [00:00<00:00, 44.6MB/s]
# Scanning '/content/datasets/Dataset-1/valid/labels' images and labels...76 found, 0 missing, 0 empty, 0 corrupt: 100% 76/76 [00:00<00:00, 1409.84it/s]
# New cache created: /content/datasets/Dataset-1/valid/labels.cache
#   0% 0/1 [00:00<?, ?it/s]wandb: Adding directory to artifact (/content/datasets/Dataset-1/valid/images)... Done. 0.2s
# wandb: Adding directory to artifact (/content/datasets/Dataset-1/valid/labels)... Done. 0.3s
# 100% 1/1 [00:00<00:00,  2.17it/s]
# 100% 76/76 [00:02<00:00, 30.72it/s]
# Mapping dataset
# 100% 76/76 [00:00<00:00, 943097.94it/s]
# YOLOv5 temporarily requires wandb version 0.12.10 or below. Some features may not work as expected.
# Downloading https://github.com/ultralytics/yolov5/releases/download/v6.0/yolov5l.pt to yolov5l.pt...
# 100% 89.2M/89.2M [00:03<00:00, 26.3MB/s]
#
# Overriding model.yaml nc=80 with nc=3
#
#                  from  n    params  module                                  arguments
#   0                -1  1      7040  models.common.Conv                      [3, 64, 6, 2, 2]
#   1                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   2                -1  3    156928  models.common.C3                        [128, 128, 3]
#   3                -1  1    295424  models.common.Conv                      [128, 256, 3, 2]
#   4                -1  6   1118208  models.common.C3                        [256, 256, 6]
#   5                -1  1   1180672  models.common.Conv                      [256, 512, 3, 2]
#   6                -1  9   6433792  models.common.C3                        [512, 512, 9]
#   7                -1  1   4720640  models.common.Conv                      [512, 1024, 3, 2]
#   8                -1  3   9971712  models.common.C3                        [1024, 1024, 3]
#   9                -1  1   2624512  models.common.SPPF                      [1024, 1024, 5]
#  10                -1  1    525312  models.common.Conv                      [1024, 512, 1, 1]
#  11                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  12           [-1, 6]  1         0  models.common.Concat                    [1]
#  13                -1  3   2757632  models.common.C3                        [1024, 512, 3, False]
#  14                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  15                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  16           [-1, 4]  1         0  models.common.Concat                    [1]
#  17                -1  3    690688  models.common.C3                        [512, 256, 3, False]
#  18                -1  1    590336  models.common.Conv                      [256, 256, 3, 2]
#  19          [-1, 14]  1         0  models.common.Concat                    [1]
#  20                -1  3   2495488  models.common.C3                        [512, 512, 3, False]
#  21                -1  1   2360320  models.common.Conv                      [512, 512, 3, 2]
#  22          [-1, 10]  1         0  models.common.Concat                    [1]
#  23                -1  3   9971712  models.common.C3                        [1024, 1024, 3, False]
#  24      [17, 20, 23]  1     43080  models.yolo.Detect                      [3, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], [256, 512, 1024]]
# Model summary: 468 layers, 46149064 parameters, 46149064 gradients, 108.0 GFLOPs
#
# Transferred 607/613 items from yolov5l.pt
# Scaled weight_decay = 0.0005
# optimizer: SGD with parameter groups 101 weight (no decay), 104 weight, 104 bias
# albumentations: version 1.0.3 required by YOLOv5, but version 0.1.12 is currently installed
# train: Scanning '/content/datasets/Dataset-1/train/labels' images and labels...252 found, 0 missing, 0 empty, 0 corrupt: 100% 252/252 [00:00<00:00, 2209.85it/s]
# train: New cache created: /content/datasets/Dataset-1/train/labels.cache
# train: Caching images (0.1GB ram): 100% 252/252 [00:03<00:00, 78.24it/s]
# val: Scanning '/content/datasets/Dataset-1/valid/labels.cache' images and labels... 76 found, 0 missing, 0 empty, 0 corrupt: 100% 76/76 [00:00<?, ?it/s]
# val: Caching images (0.0GB ram): 100% 76/76 [00:01<00:00, 46.68it/s]
# Plotting labels to runs/train/exp/labels.jpg...
#
# AutoAnchor: 3.28 anchors/target, 1.000 Best Possible Recall (BPR). Current anchors are a good fit to dataset ✅
# Image sizes 416 train, 416 val
# Using 2 dataloader workers
# Logging results to runs/train/exp
# Starting training for 600 epochs...
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      0/599     2.64G   0.09792   0.02666   0.03731        16       416: 100% 32/32 [00:09<00:00,  3.21it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 5/5 [00:01<00:00,  2.79it/s]
#                  all         76        117      0.202      0.413      0.248     0.0943
# Saving model artifact on epoch 1
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      1/599        3G   0.06738   0.02798   0.03202        21       416: 100% 32/32 [00:06<00:00,  4.98it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 5/5 [00:01<00:00,  2.75it/s]
#                  all         76        117       0.67      0.294      0.292     0.0977
# Saving model artifact on epoch 2
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      2/599        3G   0.06748   0.02343   0.02683        14       416: 100% 32/32 [00:06<00:00,  5.16it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 5/5 [00:01<00:00,  2.95it/s]
#                  all         76        117      0.367      0.514      0.285      0.107
# Saving model artifact on epoch 3
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      3/599        3G    0.0634   0.02219   0.02378         6       416: 100% 32/32 [00:06<00:00,  5.33it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 5/5 [00:01<00:00,  3.02it/s]
#                  all         76        117       0.39      0.479      0.373      0.155
# Saving model artifact on epoch 4
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      4/599        3G   0.06493   0.02385   0.02032        16       416: 100% 32/32 [00:06<00:00,  5.06it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 5/5 [00:01<00:00,  2.97it/s]
#                  all         76        117       0.43      0.417      0.373       0.17
# Saving model artifact on epoch 5
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      5/599        3G   0.05858   0.02233   0.01785         8       416: 100% 32/32 [00:06<00:00,  5.12it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 5/5 [00:01<00:00,  2.96it/s]
#                  all         76        117      0.354      0.262      0.228     0.0791
# Saving model artifact on epoch 6
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      6/599        3G   0.05514   0.02218   0.01663        16       416: 100% 32/32 [00:06<00:00,  5.25it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 5/5 [00:01<00:00,  3.00it/s]
#                  all         76        117      0.265      0.264      0.197     0.0841
# Saving model artifact on epoch 7
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      7/599        3G   0.05415   0.02314   0.01582        14       416: 100% 32/32 [00:05<00:00,  5.34it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 5/5 [00:01<00:00,  3.18it/s]
#                  all         76        117      0.156      0.426      0.184     0.0587
# Saving model artifact on epoch 8
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      8/599        3G   0.05511   0.02173   0.01618        14       416: 100% 32/32 [00:06<00:00,  5.15it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 5/5 [00:01<00:00,  3.24it/s]
#                  all         76        117      0.278      0.486      0.359      0.142
# Saving model artifact on epoch 9
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      9/599        3G   0.05424     0.021   0.01575        13       416: 100% 32/32 [00:06<00:00,  5.14it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 5/5 [00:01<00:00,  3.02it/s]
#                  all         76        117      0.335       0.46      0.379      0.225
# Saving model artifact on epoch 10
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     10/599        3G   0.04692    0.0224   0.01345        16       416: 100% 32/32 [00:06<00:00,  5.15it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 5/5 [00:01<00:00,  3.01it/s]
#                  all         76        117      0.318      0.403      0.319      0.157
# Saving model artifact on epoch 11
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     11/599        3G   0.04862   0.02278   0.01381        14       416: 100% 32/32 [00:06<00:00,  5.32it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 5/5 [00:01<00:00,  3.20it/s]
#                  all         76        117      0.433      0.551       0.51      0.248
# Saving model artifact on epoch 12
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     12/599        3G   0.04598   0.02119   0.01501        12       416: 100% 32/32 [00:06<00:00,  5.04it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 5/5 [00:01<00:00,  3.24it/s]
#                  all         76        117       0.54      0.497      0.492      0.238
# Saving model artifact on epoch 13
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     13/599        3G   0.04514    0.0224   0.01657        19       416: 100% 32/32 [00:06<00:00,  5.10it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 5/5 [00:01<00:00,  3.09it/s]
#                  all         76        117      0.546       0.44      0.466      0.256
# Saving model artifact on epoch 14
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     14/599        3G   0.04297   0.02331   0.01587        10       416: 100% 32/32 [00:06<00:00,  5.30it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 5/5 [00:01<00:00,  3.25it/s]
#                  all         76        117      0.685      0.532      0.611      0.325
# Saving model artifact on epoch 15
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     15/599        3G   0.04164   0.02203   0.01334        14       416: 100% 32/32 [00:06<00:00,  4.95it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 5/5 [00:01<00:00,  3.18it/s]
#                  all         76        117      0.402      0.504      0.443      0.214
# Saving model artifact on epoch 16
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     16/599        3G   0.04256   0.02312   0.01304        18       416: 100% 32/32 [00:06<00:00,  4.90it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 5/5 [00:01<00:00,  3.03it/s]
#                  all         76        117      0.525      0.574      0.539      0.283
# Saving model artifact on epoch 17
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     17/599        3G   0.04225   0.02209   0.01124        13       416: 100% 32/32 [00:06<00:00,  5.08it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 5/5 [00:01<00:00,  3.00it/s]
#                  all         76        117      0.547        0.6      0.565      0.343
# Saving model artifact on epoch 18
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     18/599        3G    0.0407   0.02144   0.01326        13       416: 100% 32/32 [00:06<00:00,  5.20it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 5/5 [00:01<00:00,  3.20it/s]
#                  all         76        117      0.476      0.541       0.55      0.302
# Saving model artifact on epoch 19
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     19/599        3G    0.0401    0.0209   0.01172        13       416: 100% 32/32 [00:06<00:00,  4.93it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 5/5 [00:01<00:00,  3.16it/s]
#                  all         76        117      0.443      0.598      0.564      0.322
# Saving model artifact on epoch 20
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     20/599        3G   0.04052    0.0209   0.01245        15       416: 100% 32/32 [00:05<00:00,  5.34it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 5/5 [00:01<00:00,  3.07it/s]
#                  all         76        117      0.444       0.51      0.491      0.311
# Saving model artifact on epoch 21
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     21/599        3G   0.03861   0.02167   0.01271        14       416: 100% 32/32 [00:06<00:00,  5.15it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 5/5 [00:01<00:00,  3.10it/s]
#                  all         76        117      0.532      0.589       0.57      0.324
# Saving model artifact on epoch 22
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     22/599        3G   0.03949   0.02024   0.01466        14       416: 100% 32/32 [00:06<00:00,  5.22it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 5/5 [00:01<00:00,  3.18it/s]
#                  all         76        117      0.513      0.646        0.6      0.339
# Saving model artifact on epoch 23
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     23/599        3G   0.03751   0.02255   0.01051        10       416: 100% 32/32 [00:05<00:00,  5.37it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 5/5 [00:01<00:00,  3.27it/s]
#                  all         76        117      0.449      0.695      0.592      0.306
# wandb: WARNING A graphql request initiated by the public wandb API timed out (timeout=9 sec). Create a new API with an integer timeout larger than 9, e.g., `api = wandb.Api(timeout=19)` to increase the graphql timeout.
# Saving model artifact on epoch 24
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     24/599        3G   0.03641   0.02012  0.009644        14       416: 100% 32/32 [00:06<00:00,  4.88it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 5/5 [00:01<00:00,  3.01it/s]
#                  all         76        117      0.399      0.512      0.512      0.323
# Saving model artifact on epoch 25
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     25/599        3G   0.03749    0.0213   0.01182        20       416: 100% 32/32 [00:06<00:00,  5.03it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 5/5 [00:01<00:00,  2.99it/s]
#                  all         76        117      0.578      0.553       0.57      0.364
# Saving model artifact on epoch 26
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     26/599        3G   0.03929   0.02169    0.0111        13       416: 100% 32/32 [00:06<00:00,  5.32it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 5/5 [00:01<00:00,  3.22it/s]
#                  all         76        117      0.649      0.575      0.646      0.393
# Saving model artifact on epoch 27
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     27/599        3G   0.03771   0.01956   0.01137        10       416: 100% 32/32 [00:06<00:00,  5.11it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 5/5 [00:01<00:00,  3.16it/s]
#                  all         76        117      0.697      0.616      0.694      0.379
# Saving model artifact on epoch 28
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     28/599        3G   0.03743    0.0188   0.01011         8       416: 100% 32/32 [00:05<00:00,  5.38it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 5/5 [00:01<00:00,  3.23it/s]
#                  all         76        117      0.546      0.788      0.699      0.379
# Saving model artifact on epoch 29
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     29/599        3G   0.03452   0.01978  0.009557        17       416: 100% 32/32 [00:05<00:00,  5.41it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 5/5 [00:01<00:00,  3.28it/s]
#                  all         76        117      0.731      0.512      0.623      0.323
# Saving model artifact on epoch 30
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     30/599        3G   0.03855   0.02091   0.01282        16       416: 100% 32/32 [00:06<00:00,  4.83it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 5/5 [00:01<00:00,  2.99it/s]
#                  all         76        117      0.529      0.624      0.592      0.338
# wandb: WARNING A graphql request initiated by the public wandb API timed out (timeout=9 sec). Create a new API with an integer timeout larger than 9, e.g., `api = wandb.Api(timeout=19)` to increase the graphql timeout.
# Saving model artifact on epoch 31
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     31/599        3G   0.03837   0.02068  0.009799        18       416: 100% 32/32 [00:06<00:00,  5.12it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 5/5 [00:01<00:00,  2.97it/s]
#                  all         76        117      0.553      0.703      0.651      0.376
# Saving model artifact on epoch 32
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     32/599        3G   0.03645    0.0199   0.01074        14       416: 100% 32/32 [00:06<00:00,  5.22it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 5/5 [00:01<00:00,  3.33it/s]
#                  all         76        117      0.676      0.544      0.626      0.347
# Saving model artifact on epoch 33
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     33/599        3G   0.03477   0.02053   0.01151        23       416: 100% 32/32 [00:06<00:00,  4.76it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 5/5 [00:01<00:00,  3.12it/s]
#                  all         76        117      0.665      0.538      0.629      0.364
# Saving model artifact on epoch 34
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     34/599        3G   0.03438   0.02114   0.01137        25       416: 100% 32/32 [00:06<00:00,  5.19it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 5/5 [00:01<00:00,  2.94it/s]
#                  all         76        117      0.574       0.64      0.602      0.368
# Saving model artifact on epoch 35
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     35/599        3G   0.03385   0.02025  0.008321         8       416: 100% 32/32 [00:05<00:00,  5.37it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 5/5 [00:01<00:00,  3.28it/s]
#                  all         76        117      0.633      0.647      0.613      0.366
# Saving model artifact on epoch 36
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     36/599        3G   0.03535   0.01961  0.008906        10       416: 100% 32/32 [00:06<00:00,  5.30it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 5/5 [00:01<00:00,  3.17it/s]
#                  all         76        117      0.677      0.658      0.667      0.368
# Saving model artifact on epoch 37
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     37/599        3G   0.03493   0.02081  0.007633        15       416: 100% 32/32 [00:06<00:00,  5.03it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 5/5 [00:01<00:00,  2.96it/s]
#                  all         76        117        0.6      0.633      0.659      0.422
# Saving model artifact on epoch 38
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     38/599        3G   0.03289   0.01784   0.01035         5       416: 100% 32/32 [00:06<00:00,  5.30it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 5/5 [00:01<00:00,  3.13it/s]
#                  all         76        117      0.703      0.612      0.685      0.391
# Saving model artifact on epoch 39
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     39/599        3G   0.03406   0.01941  0.007491         8       416: 100% 32/32 [00:06<00:00,  4.83it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 5/5 [00:01<00:00,  3.07it/s]
#                  all         76        117      0.534      0.723      0.635      0.389
# Saving model artifact on epoch 40
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     40/599        3G   0.03427    0.0182   0.01056         8       416: 100% 32/32 [00:06<00:00,  5.13it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 5/5 [00:01<00:00,  2.78it/s]
#                  all         76        117       0.59       0.64      0.617      0.367
# Saving model artifact on epoch 41
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     41/599        3G   0.03193   0.01915   0.00797        10       416: 100% 32/32 [00:06<00:00,  5.19it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 5/5 [00:01<00:00,  2.80it/s]
#                  all         76        117      0.633      0.601      0.611      0.377
# Saving model artifact on epoch 42
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     42/599        3G   0.03207   0.01796  0.006424        22       416: 100% 32/32 [00:06<00:00,  5.08it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 5/5 [00:01<00:00,  3.16it/s]
#                  all         76        117      0.654      0.645      0.659      0.364
# Saving model artifact on epoch 43
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     43/599        3G   0.03267     0.019  0.005902        14       416: 100% 32/32 [00:06<00:00,  4.78it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 5/5 [00:01<00:00,  2.87it/s]
#                  all         76        117      0.664      0.515       0.62       0.39
# Saving model artifact on epoch 44
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     44/599        3G   0.03606   0.01843  0.007265        13       416: 100% 32/32 [00:06<00:00,  5.30it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 5/5 [00:01<00:00,  3.19it/s]
#                  all         76        117      0.601      0.646      0.605      0.372
# Saving model artifact on epoch 45
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     45/599        3G   0.03319   0.01853   0.00671        18       416: 100% 32/32 [00:06<00:00,  4.74it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 5/5 [00:01<00:00,  2.78it/s]
#                  all         76        117      0.636      0.537       0.59      0.373
# Saving model artifact on epoch 46
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     46/599        3G   0.03269   0.01809  0.007248        12       416: 100% 32/32 [00:06<00:00,  5.23it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 5/5 [00:01<00:00,  3.23it/s]
#                  all         76        117      0.626      0.618      0.684      0.388
# Saving model artifact on epoch 47
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     47/599        3G   0.03243   0.01867  0.007312        11       416: 100% 32/32 [00:06<00:00,  4.93it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 5/5 [00:01<00:00,  3.20it/s]
#                  all         76        117      0.651      0.663      0.694        0.4
# Saving model artifact on epoch 48
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     48/599        3G   0.03135   0.01856  0.009463        15       416: 100% 32/32 [00:06<00:00,  4.82it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 5/5 [00:01<00:00,  2.95it/s]
#                  all         76        117      0.637      0.706      0.694      0.406
# Saving model artifact on epoch 49
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     49/599        3G   0.03118   0.01813   0.01109        14       416: 100% 32/32 [00:06<00:00,  5.03it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 5/5 [00:01<00:00,  2.89it/s]
#                  all         76        117      0.648      0.641      0.677      0.419
# Saving model artifact on epoch 50
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     50/599        3G   0.03044   0.01691   0.00762        14       416: 100% 32/32 [00:06<00:00,  5.17it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 5/5 [00:01<00:00,  3.23it/s]
#                  all         76        117      0.646      0.583      0.629      0.419
# Saving model artifact on epoch 51
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     51/599        3G   0.03297   0.01892    0.0061        14       416: 100% 32/32 [00:06<00:00,  5.16it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 5/5 [00:01<00:00,  3.29it/s]
#                  all         76        117      0.646      0.634      0.655      0.414
# Saving model artifact on epoch 52
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     52/599        3G   0.03185   0.01816  0.007587        12       416: 100% 32/32 [00:05<00:00,  5.39it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 5/5 [00:01<00:00,  3.27it/s]
#                  all         76        117      0.714      0.628      0.678      0.386
# Saving model artifact on epoch 53
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     53/599        3G    0.0336   0.01798  0.007179         7       416: 100% 32/32 [00:06<00:00,  4.80it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 5/5 [00:01<00:00,  3.17it/s]
#                  all         76        117      0.568       0.67      0.646      0.399
# Saving model artifact on epoch 54
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     54/599        3G   0.03223   0.01737  0.006745        14       416: 100% 32/32 [00:06<00:00,  4.92it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 5/5 [00:01<00:00,  2.88it/s]
#                  all         76        117       0.68      0.642      0.669      0.426
# Saving model artifact on epoch 55
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     55/599        3G   0.03223   0.01798  0.007226        21       416: 100% 32/32 [00:06<00:00,  5.25it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 5/5 [00:01<00:00,  3.23it/s]
#                  all         76        117      0.703      0.643      0.674      0.409
# Saving model artifact on epoch 56
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     56/599        3G    0.0342   0.01891  0.008452        14       416: 100% 32/32 [00:06<00:00,  4.70it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 5/5 [00:01<00:00,  3.04it/s]
#                  all         76        117      0.581      0.744      0.685      0.409
# Saving model artifact on epoch 57
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     57/599        3G   0.03116   0.01669   0.00625        13       416: 100% 32/32 [00:06<00:00,  4.74it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 5/5 [00:01<00:00,  2.96it/s]
#                  all         76        117      0.685       0.64      0.706       0.43
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/torch/serialization.py", line 380, in save
#     _save(obj, opened_zipfile, pickle_module, pickle_protocol)
#   File "/usr/local/lib/python3.7/dist-packages/torch/serialization.py", line 604, in _save
#     zip_file.write_record(name, storage.data_ptr(), num_bytes)
# OSError: [Errno 28] No space left on device
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "train.py", line 667, in <module>
#     main(opt)
#   File "train.py", line 562, in main
#     train(opt.hyp, opt, device, callbacks)
#   File "train.py", line 424, in train
#     torch.save(ckpt, w / f'epoch{epoch}.pt')
#   File "/usr/local/lib/python3.7/dist-packages/torch/serialization.py", line 381, in save
#     return
#   File "/usr/local/lib/python3.7/dist-packages/torch/serialization.py", line 260, in __exit__
#     self.file_like.write_end_of_file()
# RuntimeError: [enforce fail at inline_container.cc:300] . unexpected pos 174167552 vs 174167440
# Exception in thread Thread-6:
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.7/threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/lib/python3.7/dist-packages/wandb/filesync/step_upload.py", line 76, in _thread_body
#     self._handle_event(event)
#   File "/usr/local/lib/python3.7/dist-packages/wandb/filesync/step_upload.py", line 105, in _handle_event
#     self._maybe_commit_artifact(job.artifact_id)
#   File "/usr/local/lib/python3.7/dist-packages/wandb/filesync/step_upload.py", line 185, in _maybe_commit_artifact
#     callback()
#   File "/usr/local/lib/python3.7/dist-packages/wandb/sdk/internal/artifacts.py", line 186, in before_commit
#     json.dump(self._manifest.to_manifest_json(), fp, indent=4)
#   File "/usr/lib/python3.7/json/__init__.py", line 180, in dump
#     fp.write(chunk)
#   File "/usr/lib/python3.7/tempfile.py", line 620, in func_wrapper
#     return func(*args, **kwargs)
# OSError: [Errno 28] No space left on device
#
# wandb: Waiting for W&B process to finish... (failed 1). Press Control-C to abort syncing.
# Exception in thread Thread-2:
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "/usr/local/lib/python3.7/dist-packages/tensorboard/summary/writer/event_file_writer.py", line 247, in run
#     self._record_writer.flush()
#   File "/usr/local/lib/python3.7/dist-packages/tensorboard/summary/writer/record_writer.py", line 43, in flush
#     self._writer.flush()
#   File "/usr/local/lib/python3.7/dist-packages/tensorflow/python/lib/io/file_io.py", line 219, in flush
#     self._writable_file.flush()
# tensorflow.python.framework.errors_impl.ResourceExhaustedError: runs/train/exp/events.out.tfevents.1652125058.e31d652e0dee.379.0; No space left on device
#
# --- Logging error ---
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/logging/__init__.py", line 1029, in emit
#     self.flush()
#   File "/usr/lib/python3.7/logging/__init__.py", line 1009, in flush
#     self.stream.flush()
# OSError: [Errno 28] No space left on device
# Call stack:
#   File "/usr/lib/python3.7/threading.py", line 890, in _bootstrap
#     self._bootstrap_inner()
#   File "/usr/lib/python3.7/threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "/usr/local/lib/python3.7/dist-packages/wandb/sdk/internal/internal_util.py", line 51, in run
#     self._run()
#   File "/usr/local/lib/python3.7/dist-packages/wandb/sdk/internal/internal_util.py", line 102, in _run
#     self._process(record)
#   File "/usr/local/lib/python3.7/dist-packages/wandb/sdk/internal/internal.py", line 265, in _process
#     self._hm.handle(record)
#   File "/usr/local/lib/python3.7/dist-packages/wandb/sdk/internal/handler.py", line 133, in handle
#     handler(record)
#   File "/usr/local/lib/python3.7/dist-packages/wandb/sdk/internal/handler.py", line 141, in handle_request
#     logger.debug(f"handle_request: {request_type}")
# Message: 'handle_request: poll_exit'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/logging/__init__.py", line 1029, in emit
#     self.flush()
#   File "/usr/lib/python3.7/logging/__init__.py", line 1009, in flush
#     self.stream.flush()
# OSError: [Errno 28] No space left on device
# Call stack:
#   File "/usr/lib/python3.7/threading.py", line 890, in _bootstrap
#     self._bootstrap_inner()
#   File "/usr/lib/python3.7/threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "/usr/local/lib/python3.7/dist-packages/wandb/sdk/internal/internal_util.py", line 51, in run
#     self._run()
#   File "/usr/local/lib/python3.7/dist-packages/wandb/sdk/internal/internal_util.py", line 102, in _run
#     self._process(record)
#   File "/usr/local/lib/python3.7/dist-packages/wandb/sdk/internal/internal.py", line 265, in _process
#     self._hm.handle(record)
#   File "/usr/local/lib/python3.7/dist-packages/wandb/sdk/internal/handler.py", line 133, in handle
#     handler(record)
#   File "/usr/local/lib/python3.7/dist-packages/wandb/sdk/internal/handler.py", line 141, in handle_request
#     logger.debug(f"handle_request: {request_type}")
# Message: 'handle_request: poll_exit'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/logging/__init__.py", line 1029, in emit
#     self.flush()
#   File "/usr/lib/python3.7/logging/__init__.py", line 1009, in flush
#     self.stream.flush()
# OSError: [Errno 28] No space left on device
# Call stack:
#   File "/usr/lib/python3.7/threading.py", line 890, in _bootstrap
#     self._bootstrap_inner()
#   File "/usr/lib/python3.7/threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "/usr/local/lib/python3.7/dist-packages/wandb/sdk/internal/internal_util.py", line 51, in run
#     self._run()
#   File "/usr/local/lib/python3.7/dist-packages/wandb/sdk/internal/internal_util.py", line 102, in _run
#     self._process(record)
#   File "/usr/local/lib/python3.7/dist-packages/wandb/sdk/internal/internal.py", line 265, in _process
#     self._hm.handle(record)
#   File "/usr/local/lib/python3.7/dist-packages/wandb/sdk/internal/handler.py", line 133, in handle
#     handler(record)
#   File "/usr/local/lib/python3.7/dist-packages/wandb/sdk/internal/handler.py", line 141, in handle_request
#     logger.debug(f"handle_request: {request_type}")
# Message: 'handle_request: poll_exit'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/logging/__init__.py", line 1029, in emit
#     self.flush()
#   File "/usr/lib/python3.7/logging/__init__.py", line 1009, in flush
#     self.stream.flush()
# OSError: [Errno 28] No space left on device
# Call stack:
#   File "/usr/lib/python3.7/threading.py", line 890, in _bootstrap
#     self._bootstrap_inner()
#   File "/usr/lib/python3.7/threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "/usr/local/lib/python3.7/dist-packages/wandb/sdk/internal/internal_util.py", line 51, in run
#     self._run()
#   File "/usr/local/lib/python3.7/dist-packages/wandb/sdk/internal/internal_util.py", line 102, in _run
#     self._process(record)
#   File "/usr/local/lib/python3.7/dist-packages/wandb/sdk/internal/internal.py", line 265, in _process
#     self._hm.handle(record)
#   File "/usr/local/lib/python3.7/dist-packages/wandb/sdk/internal/handler.py", line 133, in handle
#     handler(record)
#   File "/usr/local/lib/python3.7/dist-packages/wandb/sdk/internal/handler.py", line 141, in handle_request
#     logger.debug(f"handle_request: {request_type}")
# Message: 'handle_request: poll_exit'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/logging/__init__.py", line 1029, in emit
#     self.flush()
#   File "/usr/lib/python3.7/logging/__init__.py", line 1009, in flush
#     self.stream.flush()
# OSError: [Errno 28] No space left on device
# Call stack:
#   File "/usr/lib/python3.7/threading.py", line 890, in _bootstrap
#     self._bootstrap_inner()
#   File "/usr/lib/python3.7/threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "/usr/local/lib/python3.7/dist-packages/wandb/sdk/internal/internal_util.py", line 51, in run
#     self._run()
#   File "/usr/local/lib/python3.7/dist-packages/wandb/sdk/internal/internal_util.py", line 102, in _run
#     self._process(record)
#   File "/usr/local/lib/python3.7/dist-packages/wandb/sdk/internal/internal.py", line 265, in _process
#     self._hm.handle(record)
#   File "/usr/local/lib/python3.7/dist-packages/wandb/sdk/internal/handler.py", line 133, in handle
#     handler(record)
#   File "/usr/local/lib/python3.7/dist-packages/wandb/sdk/internal/handler.py", line 141, in handle_request
#     logger.debug(f"handle_request: {request_type}")
# Message: 'handle_request: poll_exit'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/logging/__init__.py", line 1029, in emit
#     self.flush()
#   File "/usr/lib/python3.7/logging/__init__.py", line 1009, in flush
#     self.stream.flush()
# OSError: [Errno 28] No space left on device
# Call stack:
#   File "/usr/lib/python3.7/threading.py", line 890, in _bootstrap
#     self._bootstrap_inner()
#   File "/usr/lib/python3.7/threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "/usr/local/lib/python3.7/dist-packages/wandb/sdk/internal/internal_util.py", line 51, in run
#     self._run()
#   File "/usr/local/lib/python3.7/dist-packages/wandb/sdk/internal/internal_util.py", line 102, in _run
#     self._process(record)
#   File "/usr/local/lib/python3.7/dist-packages/wandb/sdk/internal/internal.py", line 265, in _process
#     self._hm.handle(record)
#   File "/usr/local/lib/python3.7/dist-packages/wandb/sdk/internal/handler.py", line 133, in handle
#     handler(record)
#   File "/usr/local/lib/python3.7/dist-packages/wandb/sdk/internal/handler.py", line 141, in handle_request
#     logger.debug(f"handle_request: {request_type}")
# Message: 'handle_request: poll_exit'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/logging/__init__.py", line 1029, in emit
#     self.flush()
#   File "/usr/lib/python3.7/logging/__init__.py", line 1009, in flush
#     self.stream.flush()
# OSError: [Errno 28] No space left on device
# Call stack:
#   File "/usr/lib/python3.7/threading.py", line 890, in _bootstrap
#     self._bootstrap_inner()
#   File "/usr/lib/python3.7/threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "/usr/local/lib/python3.7/dist-packages/wandb/sdk/internal/internal_util.py", line 51, in run
#     self._run()
#   File "/usr/local/lib/python3.7/dist-packages/wandb/sdk/internal/internal_util.py", line 102, in _run
#     self._process(record)
#   File "/usr/local/lib/python3.7/dist-packages/wandb/sdk/internal/internal.py", line 265, in _process
#     self._hm.handle(record)
#   File "/usr/local/lib/python3.7/dist-packages/wandb/sdk/internal/handler.py", line 133, in handle
#     handler(record)
#   File "/usr/local/lib/python3.7/dist-packages/wandb/sdk/internal/handler.py", line 141, in handle_request
#     logger.debug(f"handle_request: {request_type}")
# Message: 'handle_request: poll_exit'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/logging/__init__.py", line 1029, in emit
#     self.flush()
#   File "/usr/lib/python3.7/logging/__init__.py", line 1009, in flush
#     self.stream.flush()
# OSError: [Errno 28] No space left on device
# Call stack:
#   File "/usr/lib/python3.7/threading.py", line 890, in _bootstrap
#     self._bootstrap_inner()
#   File "/usr/lib/python3.7/threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "/usr/local/lib/python3.7/dist-packages/wandb/sdk/internal/internal_util.py", line 51, in run
#     self._run()
#   File "/usr/local/lib/python3.7/dist-packages/wandb/sdk/internal/internal_util.py", line 102, in _run
#     self._process(record)
#   File "/usr/local/lib/python3.7/dist-packages/wandb/sdk/internal/internal.py", line 265, in _process
#     self._hm.handle(record)
#   File "/usr/local/lib/python3.7/dist-packages/wandb/sdk/internal/handler.py", line 133, in handle
#     handler(record)
#   File "/usr/local/lib/python3.7/dist-packages/wandb/sdk/internal/handler.py", line 141, in handle_request
#     logger.debug(f"handle_request: {request_type}")
# Message: 'handle_request: poll_exit'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/logging/__init__.py", line 1029, in emit
#     self.flush()
#   File "/usr/lib/python3.7/logging/__init__.py", line 1009, in flush
#     self.stream.flush()
# OSError: [Errno 28] No space left on device
# Call stack:
#   File "/usr/lib/python3.7/threading.py", line 890, in _bootstrap
#     self._bootstrap_inner()
#   File "/usr/lib/python3.7/threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "/usr/local/lib/python3.7/dist-packages/wandb/sdk/internal/internal_util.py", line 51, in run
#     self._run()
#   File "/usr/local/lib/python3.7/dist-packages/wandb/sdk/internal/internal_util.py", line 102, in _run
#     self._process(record)
#   File "/usr/local/lib/python3.7/dist-packages/wandb/sdk/internal/internal.py", line 265, in _process
#     self._hm.handle(record)
#   File "/usr/local/lib/python3.7/dist-packages/wandb/sdk/internal/handler.py", line 133, in handle
#     handler(record)
#   File "/usr/local/lib/python3.7/dist-packages/wandb/sdk/internal/handler.py", line 141, in handle_request
#     logger.debug(f"handle_request: {request_type}")
# Message: 'handle_request: poll_exit'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/logging/__init__.py", line 1029, in emit
#     self.flush()
#   File "/usr/lib/python3.7/logging/__init__.py", line 1009, in flush
#     self.stream.flush()
# OSError: [Errno 28] No space left on device
# Call stack:
#   File "/usr/lib/python3.7/threading.py", line 890, in _bootstrap
#     self._bootstrap_inner()
#   File "/usr/lib/python3.7/threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "/usr/local/lib/python3.7/dist-packages/wandb/sdk/internal/internal_util.py", line 51, in run
#     self._run()
#   File "/usr/local/lib/python3.7/dist-packages/wandb/sdk/internal/internal_util.py", line 103, in _run
#     self._finish()
#   File "/usr/local/lib/python3.7/dist-packages/wandb/sdk/internal/internal.py", line 268, in _finish
#     self._hm.finish()
#   File "/usr/local/lib/python3.7/dist-packages/wandb/sdk/internal/handler.py", line 806, in finish
#     logger.info("shutting down handler")
# Message: 'shutting down handler'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/logging/__init__.py", line 1029, in emit
#     self.flush()
#   File "/usr/lib/python3.7/logging/__init__.py", line 1009, in flush
#     self.stream.flush()
# OSError: [Errno 28] No space left on device
# Call stack:
#   File "/usr/local/lib/python3.7/dist-packages/wandb/sdk/wandb_run.py", line 1905, in <lambda>
#     atexit.register(lambda: self._atexit_cleanup())
#   File "/usr/local/lib/python3.7/dist-packages/wandb/sdk/wandb_run.py", line 1876, in _atexit_cleanup
#     self._on_finish()
#   File "/usr/local/lib/python3.7/dist-packages/wandb/sdk/wandb_run.py", line 1996, in _on_finish
#     logger.info(f"got exit ret: {self._poll_exit_response}")
# Message: 'got exit ret: None'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/logging/__init__.py", line 1029, in emit
#     self.flush()
#   File "/usr/lib/python3.7/logging/__init__.py", line 1009, in flush
#     self.stream.flush()
# OSError: [Errno 28] No space left on device
# Call stack:
#   File "/usr/local/lib/python3.7/dist-packages/wandb/sdk/wandb_run.py", line 1905, in <lambda>
#     atexit.register(lambda: self._atexit_cleanup())
#   File "/usr/local/lib/python3.7/dist-packages/wandb/sdk/wandb_run.py", line 1876, in _atexit_cleanup
#     self._on_finish()
#   File "/usr/local/lib/python3.7/dist-packages/wandb/sdk/wandb_run.py", line 1996, in _on_finish
#     logger.info(f"got exit ret: {self._poll_exit_response}")
# Message: 'got exit ret: None'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/logging/__init__.py", line 1029, in emit
#     self.flush()
#   File "/usr/lib/python3.7/logging/__init__.py", line 1009, in flush
#     self.stream.flush()
# OSError: [Errno 28] No space left on device
# Call stack:
# ...
#   File "/usr/lib/python3.7/logging/__init__.py", line 1029, in emit
#     self.flush()
#   File "/usr/lib/python3.7/logging/__init__.py", line 1009, in flush
#     self.stream.flush()
# OSError: [Errno 28] No space left on device
# Call stack:
#   File "/usr/local/lib/python3.7/dist-packages/wandb/sdk/wandb_run.py", line 1905, in <lambda>
#     atexit.register(lambda: self._atexit_cleanup())
#   File "/usr/local/lib/python3.7/dist-packages/wandb/sdk/wandb_run.py", line 1876, in _atexit_cleanup
#     self._on_finish()
#   File "/usr/local/lib/python3.7/dist-packages/wandb/sdk/wandb_run.py", line 1996, in _on_finish
#     logger.info(f"got exit ret: {self._poll_exit_response}")
# Message: 'got exit ret: None'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/logging/__init__.py", line 1029, in emit
#     self.flush()
#   File "/usr/lib/python3.7/logging/__init__.py", line 1009, in flush
#     self.stream.flush()
# OSError: [Errno 28] No space left on device
# Call stack:
#   File "/usr/local/lib/python3.7/dist-packages/wandb/sdk/wandb_run.py", line 1905, in <lambda>
#     atexit.register(lambda: self._atexit_cleanup())
#   File "/usr/local/lib/python3.7/dist-packages/wandb/sdk/wandb_run.py", line 1876, in _atexit_cleanup
#     self._on_finish()
#   File "/usr/local/lib/python3.7/dist-packages/wandb/sdk/wandb_run.py", line 1996, in _on_finish
#     logger.info(f"got exit ret: {self._poll_exit_response}")
# Message: 'got exit ret: None'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/logging/__init__.py", line 1029, in emit
#     self.flush()
#   File "/usr/lib/python3.7/logging/__init__.py", line 1009, in flush
#     self.stream.flush()
# OSError: [Errno 28] No space left on device
# Call stack:
#   File "/usr/local/lib/python3.7/dist-packages/wandb/sdk/wandb_run.py", line 1905, in <lambda>
#     atexit.register(lambda: self._atexit_cleanup())
#   File "/usr/local/lib/python3.7/dist-packages/wandb/sdk/wandb_run.py", line 1876, in _atexit_cleanup
#     self._on_finish()
#   File "/usr/local/lib/python3.7/dist-packages/wandb/sdk/wandb_run.py", line 1996, in _on_finish
#     logger.info(f"got exit ret: {self._poll_exit_response}")
# Message: 'got exit ret: None'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/logging/__init__.py", line 1029, in emit
#     self.flush()
#   File "/usr/lib/python3.7/logging/__init__.py", line 1009, in flush
#     self.stream.flush()
# OSError: [Errno 28] No space left on device
# Call stack:
#   File "/usr/local/lib/python3.7/dist-packages/wandb/sdk/wandb_run.py", line 1905, in <lambda>
#     atexit.register(lambda: self._atexit_cleanup())
#   File "/usr/local/lib/python3.7/dist-packages/wandb/sdk/wandb_run.py", line 1876, in _atexit_cleanup
#     self._on_finish()
#   File "/usr/local/lib/python3.7/dist-packages/wandb/sdk/wandb_run.py", line 1996, in _on_finish
#     logger.info(f"got exit ret: {self._poll_exit_response}")
# Message: 'got exit ret: None'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/logging/__init__.py", line 1029, in emit
#     self.flush()
#   File "/usr/lib/python3.7/logging/__init__.py", line 1009, in flush
#     self.stream.flush()
# OSError: [Errno 28] No space left on device
# Call stack:
#   File "/usr/local/lib/python3.7/dist-packages/wandb/sdk/wandb_run.py", line 1905, in <lambda>
#     atexit.register(lambda: self._atexit_cleanup())
#   File "/usr/local/lib/python3.7/dist-packages/wandb/sdk/wandb_run.py", line 1876, in _atexit_cleanup
#     self._on_finish()
#   File "/usr/local/lib/python3.7/dist-packages/wandb/sdk/wandb_run.py", line 1996, in _on_finish
#     logger.info(f"got exit ret: {self._poll_exit_response}")
# Message: 'got exit ret: None'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/logging/__init__.py", line 1029, in emit
#     self.flush()
#   File "/usr/lib/python3.7/logging/__init__.py", line 1009, in flush
#     self.stream.flush()
# OSError: [Errno 28] No space left on device
# Call stack:
#   File "/usr/local/lib/python3.7/dist-packages/wandb/sdk/wandb_run.py", line 1905, in <lambda>
#     atexit.register(lambda: self._atexit_cleanup())
#   File "/usr/local/lib/python3.7/dist-packages/wandb/sdk/wandb_run.py", line 1876, in _atexit_cleanup
#     self._on_finish()
#   File "/usr/local/lib/python3.7/dist-packages/wandb/sdk/wandb_run.py", line 1996, in _on_finish
#     logger.info(f"got exit ret: {self._poll_exit_response}")
# Message: 'got exit ret: None'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/logging/__init__.py", line 1029, in emit
#     self.flush()
#   File "/usr/lib/python3.7/logging/__init__.py", line 1009, in flush
#     self.stream.flush()
# OSError: [Errno 28] No space left on device
# Call stack:
#   File "/usr/local/lib/python3.7/dist-packages/wandb/sdk/wandb_run.py", line 1905, in <lambda>
#     atexit.register(lambda: self._atexit_cleanup())
#   File "/usr/local/lib/python3.7/dist-packages/wandb/sdk/wandb_run.py", line 1876, in _atexit_cleanup
#     self._on_finish()
#   File "/usr/local/lib/python3.7/dist-packages/wandb/sdk/wandb_run.py", line 1996, in _on_finish
#     logger.info(f"got exit ret: {self._poll_exit_response}")
# Message: 'got exit ret: None'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/logging/__init__.py", line 1029, in emit
#     self.flush()
#   File "/usr/lib/python3.7/logging/__init__.py", line 1009, in flush
#     self.stream.flush()
# OSError: [Errno 28] No space left on device
# Call stack:
#   File "/usr/local/lib/python3.7/dist-packages/wandb/sdk/wandb_run.py", line 1905, in <lambda>
#     atexit.register(lambda: self._atexit_cleanup())
#   File "/usr/local/lib/python3.7/dist-packages/wandb/sdk/wandb_run.py", line 1876, in _atexit_cleanup
#     self._on_finish()
#   File "/usr/local/lib/python3.7/dist-packages/wandb/sdk/wandb_run.py", line 1996, in _on_finish
#     logger.info(f"got exit ret: {self._poll_exit_response}")
# Message: 'got exit ret: None'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/logging/__init__.py", line 1029, in emit
#     self.flush()
#   File "/usr/lib/python3.7/logging/__init__.py", line 1009, in flush
#     self.stream.flush()
# OSError: [Errno 28] No space left on device
# Call stack:
#   File "/usr/local/lib/python3.7/dist-packages/wandb/sdk/wandb_run.py", line 1905, in <lambda>
#     atexit.register(lambda: self._atexit_cleanup())
#   File "/usr/local/lib/python3.7/dist-packages/wandb/sdk/wandb_run.py", line 1876, in _atexit_cleanup
#     self._on_finish()
#   File "/usr/local/lib/python3.7/dist-packages/wandb/sdk/wandb_run.py", line 1996, in _on_finish
#     logger.info(f"got exit ret: {self._poll_exit_response}")
# Message: 'got exit ret: None'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/logging/__init__.py", line 1029, in emit
#     self.flush()
#   File "/usr/lib/python3.7/logging/__init__.py", line 1009, in flush
#     self.stream.flush()
# OSError: [Errno 28] No space left on device
# Call stack:
#   File "/usr/local/lib/python3.7/dist-packages/wandb/sdk/wandb_run.py", line 1905, in <lambda>
#     atexit.register(lambda: self._atexit_cleanup())
#   File "/usr/local/lib/python3.7/dist-packages/wandb/sdk/wandb_run.py", line 1876, in _atexit_cleanup
#     self._on_finish()
#   File "/usr/local/lib/python3.7/dist-packages/wandb/sdk/wandb_run.py", line 1996, in _on_finish
#     logger.info(f"got exit ret: {self._poll_exit_response}")
# Message: 'got exit ret: None'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/logging/__init__.py", line 1029, in emit
#     self.flush()
#   File "/usr/lib/python3.7/logging/__init__.py", line 1009, in flush
#     self.stream.flush()
# OSError: [Errno 28] No space left on device
# Call stack:
#   File "/usr/local/lib/python3.7/dist-packages/wandb/sdk/wandb_run.py", line 1905, in <lambda>
#     atexit.register(lambda: self._atexit_cleanup())
#   File "/usr/local/lib/python3.7/dist-packages/wandb/sdk/wandb_run.py", line 1876, in _atexit_cleanup
#     self._on_finish()
#   File "/usr/local/lib/python3.7/dist-packages/wandb/sdk/wandb_run.py", line 1996, in _on_finish
#     logger.info(f"got exit ret: {self._poll_exit_response}")
# Message: 'got exit ret: None'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/logging/__init__.py", line 1029, in emit
#     self.flush()
#   File "/usr/lib/python3.7/logging/__init__.py", line 1009, in flush
#     self.stream.flush()
# OSError: [Errno 28] No space left on device
# Call stack:
#   File "/usr/local/lib/python3.7/dist-packages/wandb/sdk/wandb_run.py", line 1905, in <lambda>
#     atexit.register(lambda: self._atexit_cleanup())
#   File "/usr/local/lib/python3.7/dist-packages/wandb/sdk/wandb_run.py", line 1876, in _atexit_cleanup
#     self._on_finish()
#   File "/usr/local/lib/python3.7/dist-packages/wandb/sdk/wandb_run.py", line 1996, in _on_finish
#     logger.info(f"got exit ret: {self._poll_exit_response}")
# Message: 'got exit ret: None'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/logging/__init__.py", line 1029, in emit
#     self.flush()
#   File "/usr/lib/python3.7/logging/__init__.py", line 1009, in flush
#     self.stream.flush()
# OSError: [Errno 28] No space left on device
# Call stack:
#   File "/usr/local/lib/python3.7/dist-packages/wandb/sdk/wandb_run.py", line 1905, in <lambda>
#     atexit.register(lambda: self._atexit_cleanup())
#   File "/usr/local/lib/python3.7/dist-packages/wandb/sdk/wandb_run.py", line 1876, in _atexit_cleanup
#     self._on_finish()
#   File "/usr/local/lib/python3.7/dist-packages/wandb/sdk/wandb_run.py", line 1996, in _on_finish
#     logger.info(f"got exit ret: {self._poll_exit_response}")
# Message: 'got exit ret: None'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/logging/__init__.py", line 1029, in emit
#     self.flush()
#   File "/usr/lib/python3.7/logging/__init__.py", line 1009, in flush
#     self.stream.flush()
# OSError: [Errno 28] No space left on device
# Call stack:
#   File "/usr/local/lib/python3.7/dist-packages/wandb/sdk/wandb_run.py", line 1905, in <lambda>
#     atexit.register(lambda: self._atexit_cleanup())
#   File "/usr/local/lib/python3.7/dist-packages/wandb/sdk/wandb_run.py", line 1876, in _atexit_cleanup
#     self._on_finish()
#   File "/usr/local/lib/python3.7/dist-packages/wandb/sdk/wandb_run.py", line 1996, in _on_finish
#     logger.info(f"got exit ret: {self._poll_exit_response}")
# Message: 'got exit ret: None'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/logging/__init__.py", line 1029, in emit
#     self.flush()
#   File "/usr/lib/python3.7/logging/__init__.py", line 1009, in flush
#     self.stream.flush()
# OSError: [Errno 28] No space left on device
# Call stack:
#   File "/usr/local/lib/python3.7/dist-packages/wandb/sdk/wandb_run.py", line 1905, in <lambda>
#     atexit.register(lambda: self._atexit_cleanup())
#   File "/usr/local/lib/python3.7/dist-packages/wandb/sdk/wandb_run.py", line 1876, in _atexit_cleanup
#     self._on_finish()
#   File "/usr/local/lib/python3.7/dist-packages/wandb/sdk/wandb_run.py", line 1996, in _on_finish
#     logger.info(f"got exit ret: {self._poll_exit_response}")
# Message: 'got exit ret: None'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/logging/__init__.py", line 1029, in emit
#     self.flush()
#   File "/usr/lib/python3.7/logging/__init__.py", line 1009, in flush
#     self.stream.flush()
# OSError: [Errno 28] No space left on device
# Call stack:
#   File "/usr/local/lib/python3.7/dist-packages/wandb/sdk/wandb_run.py", line 1905, in <lambda>
#     atexit.register(lambda: self._atexit_cleanup())
#   File "/usr/local/lib/python3.7/dist-packages/wandb/sdk/wandb_run.py", line 1876, in _atexit_cleanup
#     self._on_finish()
#   File "/usr/local/lib/python3.7/dist-packages/wandb/sdk/wandb_run.py", line 1996, in _on_finish
#     logger.info(f"got exit ret: {self._poll_exit_response}")
# Message: 'got exit ret: None'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/logging/__init__.py", line 1029, in emit
#     self.flush()
#   File "/usr/lib/python3.7/logging/__init__.py", line 1009, in flush
#     self.stream.flush()
# OSError: [Errno 28] No space left on device
# Call stack:
#   File "/usr/local/lib/python3.7/dist-packages/wandb/sdk/wandb_run.py", line 1905, in <lambda>
#     atexit.register(lambda: self._atexit_cleanup())
#   File "/usr/local/lib/python3.7/dist-packages/wandb/sdk/wandb_run.py", line 1876, in _atexit_cleanup
#     self._on_finish()
#   File "/usr/local/lib/python3.7/dist-packages/wandb/sdk/wandb_run.py", line 1996, in _on_finish
#     logger.info(f"got exit ret: {self._poll_exit_response}")
# Message: 'got exit ret: None'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/logging/__init__.py", line 1029, in emit
#     self.flush()
#   File "/usr/lib/python3.7/logging/__init__.py", line 1009, in flush
#     self.stream.flush()
# OSError: [Errno 28] No space left on device
# Call stack:
#   File "/usr/local/lib/python3.7/dist-packages/wandb/sdk/wandb_run.py", line 1905, in <lambda>
#     atexit.register(lambda: self._atexit_cleanup())
#   File "/usr/local/lib/python3.7/dist-packages/wandb/sdk/wandb_run.py", line 1876, in _atexit_cleanup
#     self._on_finish()
#   File "/usr/local/lib/python3.7/dist-packages/wandb/sdk/wandb_run.py", line 1996, in _on_finish
#     logger.info(f"got exit ret: {self._poll_exit_response}")
# Message: 'got exit ret: None'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/logging/__init__.py", line 1029, in emit
#     self.flush()
#   File "/usr/lib/python3.7/logging/__init__.py", line 1009, in flush
#     self.stream.flush()
# OSError: [Errno 28] No space left on device
# Call stack:
#   File "/usr/local/lib/python3.7/dist-packages/wandb/sdk/wandb_run.py", line 1905, in <lambda>
#     atexit.register(lambda: self._atexit_cleanup())
#   File "/usr/local/lib/python3.7/dist-packages/wandb/sdk/wandb_run.py", line 1876, in _atexit_cleanup
#     self._on_finish()
#   File "/usr/local/lib/python3.7/dist-packages/wandb/sdk/wandb_run.py", line 1996, in _on_finish
#     logger.info(f"got exit ret: {self._poll_exit_response}")
# Message: 'got exit ret: None'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/logging/__init__.py", line 1029, in emit
#     self.flush()
#   File "/usr/lib/python3.7/logging/__init__.py", line 1009, in flush
#     self.stream.flush()
# OSError: [Errno 28] No space left on device
# Call stack:
#   File "/usr/local/lib/python3.7/dist-packages/wandb/sdk/wandb_run.py", line 1905, in <lambda>
#     atexit.register(lambda: self._atexit_cleanup())
#   File "/usr/local/lib/python3.7/dist-packages/wandb/sdk/wandb_run.py", line 1876, in _atexit_cleanup
#     self._on_finish()
#   File "/usr/local/lib/python3.7/dist-packages/wandb/sdk/wandb_run.py", line 1996, in _on_finish
#     logger.info(f"got exit ret: {self._poll_exit_response}")
# Message: 'got exit ret: None'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/logging/__init__.py", line 1029, in emit
#     self.flush()
#   File "/usr/lib/python3.7/logging/__init__.py", line 1009, in flush
#     self.stream.flush()
# OSError: [Errno 28] No space left on device
# Call stack:
#   File "/usr/local/lib/python3.7/dist-packages/wandb/sdk/wandb_run.py", line 1905, in <lambda>
#     atexit.register(lambda: self._atexit_cleanup())
#   File "/usr/local/lib/python3.7/dist-packages/wandb/sdk/wandb_run.py", line 1876, in _atexit_cleanup
#     self._on_finish()
#   File "/usr/local/lib/python3.7/dist-packages/wandb/sdk/wandb_run.py", line 1996, in _on_finish
#     logger.info(f"got exit ret: {self._poll_exit_response}")
# Message: 'got exit ret: None'
# Arguments: ()

# %%
# !python detect.py --weights weights/last_yolov5s_custom.pt --img 416 --conf 0.4 --source ../test_infer

# %%
# PyTorch Hub
import torch

# Model
model = torch.hub.load('ultralytics/yolov5', 'yolov5s')

# Images
dir = 'https://ultralytics.com/images/'
imgs = [dir + f for f in ('zidane.jpg', 'bus.jpg')]  # batch of images

# Inference
results = model(imgs)
results.print()  # or .show(), .save()
